# %% [markdown]
# ## The first step is to map the classes into numerical data

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset

# %%
path_1_2="/Users/sachin/Downloads/Assessing Labels/Calculate Krippendorfs Alpha/Participants_1_2.xlsx"
path_3_4="/Users/sachin/Downloads/Assessing Labels/Calculate Krippendorfs Alpha/Participants_3_4.xlsx"
path_5_6="/Users/sachin/Downloads/Assessing Labels/Calculate Krippendorfs Alpha/Participants_5_6.xlsx"
path_1_6="/Users/sachin/Downloads/Assessing Labels/Calculate Krippendorfs Alpha/Participants_1_6.xlsx"
df_1_2 = pd.DataFrame()
df_3_4 = pd.DataFrame()
df_5_6 = pd.DataFrame()
df_1_6 = pd.DataFrame()

df_1_2 = pd.read_excel(path_1_2, sheet_name='Malayalam_Sentences')
df_3_4 = pd.read_excel(path_3_4, sheet_name='Malayalam_Sentences')
df_5_6 = pd.read_excel(path_5_6, sheet_name='Malayalam_Sentences')
df_1_6 = pd.read_excel(path_1_6, sheet_name='Malayalam_Sentences')

result=pd.concat([df_1_2,df_3_4,df_5_6,df_1_6])
print (result)
# Out:
#               id                                               text  \
# 0       ml_sen_1            Bollywood film Newton inte remake aano?
# 1       ml_sen_2  endukond viewrs koodunnilla ?? ippozhum 2.8m a...
# 2       ml_sen_3  Mara paazhu mega mairananil ninnum ethil koodu...
# 3       ml_sen_4                       Video nay cang xem cang thit
# 4       ml_sen_5  Sunny chechiye kaanan vannathu njan maathram aano
# ..           ...                                                ...
# 143  ml_sen_1344                          143k views and 145k likes
# 144  ml_sen_1345               Nasik doll tiltle bgm aane highlight
# 145  ml_sen_1346  Mohanlalile ishtapetta vekthiyayirunnu njan pa...
# 146  ml_sen_1347            ivaruku ivlo age nu sonna evan nambuvan
# 147  ml_sen_1348  Kanditt Amala Paul Aadai tamil mattoru version...
#
#       Participant 1  Participant 2 Participant 3 Participant 4 Participant 5  \
# ...

# %% [markdown]
# ### Map the classes into numerical data

# %%
print(result['Participant 1'].unique())

mappingDict = {'Positive':0 , 'Negative':1 ,'Neutral':2 ,'Mixed feelings':3, 'Not-Malayalam':4, '*':'*'} 


result['Participant 1_Numeric'] = result['Participant 1'].map(mappingDict)
result['Participant 2_Numeric'] = result['Participant 2'].map(mappingDict)
result['Participant 3_Numeric'] = result['Participant 3'].map(mappingDict)
result['Participant 4_Numeric'] = result['Participant 4'].map(mappingDict)
result['Participant 5_Numeric'] = result['Participant 5'].map(mappingDict)
result['Participant 6_Numeric'] = result['Participant 6'].map(mappingDict)


result['Participant 1_Numeric'] = result['Participant 1_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)
result['Participant 2_Numeric'] = result['Participant 2_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)
result['Participant 3_Numeric'] = result['Participant 3_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)
result['Participant 4_Numeric'] = result['Participant 4_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)
result['Participant 5_Numeric'] = result['Participant 5_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)
result['Participant 6_Numeric'] = result['Participant 6_Numeric'].apply(lambda x: '*' if pd.isna(x) else x)


print(result)

# result.to_excel(f'Combined_File_For_Evaluating_Alpha.xlsx', index=False)
# Out:
# ['Neutral' 'Mixed feelings' 'Negative' 'Not-Malayalam' 'Positive' nan]
#               id                                               text  \
# 0       ml_sen_1            Bollywood film Newton inte remake aano?
# 1       ml_sen_2  endukond viewrs koodunnilla ?? ippozhum 2.8m a...
# 2       ml_sen_3  Mara paazhu mega mairananil ninnum ethil koodu...
# 3       ml_sen_4                       Video nay cang xem cang thit
# 4       ml_sen_5  Sunny chechiye kaanan vannathu njan maathram aano
# ..           ...                                                ...
# 143  ml_sen_1344                          143k views and 145k likes
# 144  ml_sen_1345               Nasik doll tiltle bgm aane highlight
# 145  ml_sen_1346  Mohanlalile ishtapetta vekthiyayirunnu njan pa...
# 146  ml_sen_1347            ivaruku ivlo age nu sonna evan nambuvan
# 147  ml_sen_1348  Kanditt Amala Paul Aadai tamil mattoru version...
#
#       Participant 1  Participant 2 Participant 3 Participant 4 Participant 5  \
# ...

# %%
#Converting to string array for input
p1=" ".join(result['Participant 1_Numeric'].astype(str))
p2=" ".join(result['Participant 2_Numeric'].astype(str))
p3=" ".join(result['Participant 3_Numeric'].astype(str))
p4=" ".join(result['Participant 4_Numeric'].astype(str))
p5=" ".join(result['Participant 5_Numeric'].astype(str))
p6=" ".join(result['Participant 6_Numeric'].astype(str))

combined_strings=[p1,p2,p3,p4,p5,p6]


array = [d.split() for d in combined_strings]
# print(array[5])
# Out:
# ['*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*
# ...

# %%
def nominal_metric(a, b):
    return a != b

def interval_metric(a, b):
    return (a-b)**2

def ratio_metric(a, b):
    return ((a-b)/(a+b))**2

def krippendorff_alpha(data, metric=interval_metric, force_vecmath=False, convert_items=float, missing_items=None):
    
    # number of coders
    m = len(data)
    
    # set of constants identifying missing values
    if missing_items is None:
        maskitems = []
    else:
        maskitems = list(missing_items)
    if np is not None:
        maskitems.append(np.ma.masked_singleton)
    
    # convert input data to a dict of items
    units = {}
    for d in data:
        try:
            # try if d behaves as a dict
            diter = d.items()
        except AttributeError:
            # sequence assumed for d
            diter = enumerate(d)
            
        for it, g in diter:
            if g not in maskitems:
                try:
                    its = units[it]
                except KeyError:
                    its = []
                    units[it] = its
                its.append(convert_items(g))


    units = dict((it, d) for it, d in units.items() if len(d) > 1)  # units with pairable values
    n = sum(len(pv) for pv in units.values())  # number of pairable values
    
    if n == 0:
        raise ValueError("No items to compare.")
    
    np_metric = (np is not None) and ((metric in (interval_metric, nominal_metric, ratio_metric)) or force_vecmath)
    
    Do = 0.
    for grades in units.values():
        if np_metric:
            gr = np.asarray(grades)
            Du = sum(np.sum(metric(gr, gri)) for gri in gr)
        else:
            Du = sum(metric(gi, gj) for gi in grades for gj in grades)
        Do += Du/float(len(grades)-1)
    Do /= float(n)

    if Do == 0:
        return 1.

    De = 0.
    for g1 in units.values():
        if np_metric:
            d1 = np.asarray(g1)
            for g2 in units.values():
                De += sum(np.sum(metric(d1, gj)) for gj in g2)
        else:
            for g2 in units.values():
                De += sum(metric(gi, gj) for gi in g1 for gj in g2)
    De /= float(n*(n-1))

    return 1.-Do/De if (Do and De) else 1.


if __name__ == '__main__': 
    print("Example from http://en.wikipedia.org/wiki/Krippendorff's_Alpha")


    missing = '*' # indicator for missing values
    array = [d.split() for d in combined_strings]  # convert to 2D list of string items
    print(array)
    print("nominal metric: %.3f" % krippendorff_alpha(array, nominal_metric, missing_items=missing))
    print("interval metric: %.3f" % krippendorff_alpha(array, interval_metric, missing_items=missing))
# Out:
# Example from http://en.wikipedia.org/wiki/Krippendorff's_Alpha
# ...
